# %% [markdown]
# # Tugas Data Mining Raihanudin Rafif (251012000080)
# **Kepada Yth. Bapak DR. Ir AGUNG BUDI SUSANTO MM,**
#
# Berikut saya lampirkan hasil pengerjaan tugas Mata Kuliah Data Mining. Terlampir 7 analisis yang telah saya kerjakan menggunakan Python di Google Colab.
#
# Program ini sudah terintegrasi dengan Git, jadi Bapak dapat mengakses dan menjalankan simulasi program secara langsung melalui tautan di bawah ini:
#
# ### 1. K-Means
# Program analisis dengan model K-Means menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/kmeans_analysis.ipynb)**
#
# ### 2. PCA
# Program analisis PCA menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/pca_analysis.ipynb)**
#
# ### 3. Sentimen Analysis
# Program Sentimen Analysis menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/sentimen_analisis.ipynb)**
#
# ### 4. Latent Dirichlet Alocation (LDA)
# Program analisis LDA menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/lda_analysis.ipynb)**
#
# ### 5. Bitterm Topic Model (BTM)
# Program analisis BTM menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/btm_analysis.ipynb)**
#
# ### 6. BERTopic
# Program implementasi BERTopic menggunakan python.
# 👉 **[Klik Disini untuk Membuka](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/bertopic_analysis.ipynb)**
#
# ### 7. Chatbot HRD
# Aplikasi tanya jawab otomatis seputar aturan kepegawaian
# 👉 **[Klik Disini untuk Membuka Chatbot](https://colab.research.google.com/github/rhnrafif/datamining_1/blob/main/chatbot.ipynb)**
#
# ---
# **Catatan Teknis:**
# 1. Setelah tautan terbuka, silakan klik menu **Runtime > Run All** untuk menjalankan program.
# 2. Tunggu sebentar hingga aplikasi muncul.
# 3. Jika ingin melihat dataset, bisa akses 🔗 **[Link ini](https://github.com/rhnrafif/datamining_1/tree/main/data)**
#
# Terima kasih atas perhatian dan bimbingan Bapak.
#
# **Hormat Saya,**
#
# **Raihanudin Rafif**
# [251012000080]
